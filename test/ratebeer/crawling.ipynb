# %%
from bs4 import BeautifulSoup
import requests

# %%
html = "styles/IPA.html"
with open(html) as f:
    soup = BeautifulSoup(f, ["lxml", "xml"])

# %%
result = soup.findAll('A')
result = result[1:]
links = map(lambda x: x['HREF'],result)

# %%
links
# Out:
# [u'/beer/stone-india-pale-ale-ipa/422/',
#  u'/beer/sierra-nevada-celebration-ale/370/',
#  u'/beer/bells-two-hearted-ale/1502/',
#  u'/beer/dogfish-head-60-minute-ipa/7431/',
#  u'/beer/sierra-nevada-torpedo-extra-ipa/59261/',
#  u'/beer/victory-hopdevil/618/',
#  u'/beer/bear-republic-racer-5-ipa/1608/',
#  u'/beer/founders-centennial-ipa/3168/',
#  u'/beer/lagunitas-india-pale-ale/6887/',
#  u'/beer/green-flash-west-coast-ipa-2013/44905/',
#  u'/beer/great-divide-titan-ipa/25083/',
#  u'/beer/ballast-point-sculpin-ipa/50008/',
#  u'/beer/anderson-valley-hop-ottin-ipa/336/',
#  u'/beer/goose-island-india-pale-ale/814/',
#  u'/beer/rogue-brutal-ipa/581/',
#  u'/beer/alesmith-ipa/14396/',
#  u'/beer/brooklyn-east-india-pale-ale/530/',
#  u'/beer/sierra-nevada-harvest-wet-hop-ipa--northern-hemisphere/131958/',
#  u'/beer/avery-ipa/67/',
#  u'/beer/smuttynose-ipa/32134/',
#  u'/beer/flying-dog-raging-bitch/110932/',
#  u'/beer/founders-reds-rye-ipa/30010/',
# ...
