# %%
import json

# %%
#with open("incomplete_beerdata.json", "r") as f:
with open("allbeerdata.json", "r") as f:
    data = json.load(f)
with open("topbeers.json", "r") as f:
    datatop = json.load(f)

# %%
results = data['results']
results.keys()

topresults = datatop['results']

beerData = results['beer']
beerData += topresults['beer'] #append to list

beer = beerData[1]
print beer.keys()
beer['style']

def mappy(beer):
    x = {}
    x['Style'] = beer['style']['text']
    brewery = beer['brewery']['text']
    if "Brewed by" in brewery:
        brewery = brewery.split("Brewed by")[1]
    elif "Formerly brewed at" in brewery:
        brewery = brewery.split("Formerly brewed at")[1]
    elif "Brewed at" in brewery:
        brewery = brewery.split("Brewed at")[0]
    else:
        print "UH OH"
        print brewery
    x['Brewery'] = brewery
    beer.update(x)
    del beer['brewery']
    del beer['style']

map(mappy, beerData)

#ignore beerinfo for now
#results['beerinfo']

df_raw = pd.DataFrame(beerData)
# Out:
# [u'style', u'description', u'name', u'brewery']

# %%
print df_raw.count()
a = df_raw[df_raw['description'].notnull()]
df = a[a['description'] != '']
df = df[df.description.str.len() > 40]
df = df.drop_duplicates()
# Out:
# Brewery        9155
# Style          9155
# description    9153
# name           9155
# dtype: int64

# %%
df = df.sort(columns='Style')

# %% [markdown]
# ## NLP Stuff

# %%
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
import scipy
import collections
import re

# %%
#ipas = df[df['Style'] == 'India Pale Ale (IPA)']
#ipas = df[df['Style'] == 'Amber Ale']
#df = ipas
corpus = df['description']

remove_list = []

for cor,i in zip(corpus, corpus.index):
    if type(cor) != unicode:
        print i,cor
        remove_list.append(i)

df = df.drop( remove_list)
corpus = corpus.drop( remove_list)

print "END"

for cor,i in zip(corpus, corpus.index):
    if type(cor) != unicode:
        print i,cor
        remove_list.append(i)


#print corpus.values[-50:]
# Out:
# END

# %%
"""
import nltk
import string

from sklearn.feature_extraction.text import TfidfVectorizer
#from nltk.stem.porter import PorterStemmer

token_list = []
#stemmer = PorterStemmer()

def stem_tokens(tokens, stemmer):
    stemmed = []
    for item in tokens:
        stemmed.append(stemmer.stem(item))
    return stemmed

def tokenize(text):
    tokens = nltk.word_tokenize(text)
    #stems = stem_tokens(tokens, stemmer)
    return tokens #stems

text = mycorpus[1000]
lowers = text.lower()
no_punctuation = lowers.translate(string.punctuation)
token_list.append(no_punctuation)

print token_list
#this can take some time
#tfidf = TfidfVectorizer(tokenizer=tokenize, stop_words='english')
#tfs = tfidf.fit_transform(token_dict.values())
"""
# Out:
# "\nimport nltk\nimport string\n\nfrom sklearn.feature_extraction.text import TfidfVectorizer\n#from nltk.stem.porter import PorterStemmer\n\ntoken_list = []\n#stemmer = PorterStemmer()\n\ndef stem_tokens(tokens, stemmer):\n    stemmed = []\n    for item in tokens:\n        stemmed.append(stemmer.stem(item))\n    return stemmed\n\ndef tokenize(text):\n    tokens = nltk.word_tokenize(text)\n    #stems = stem_tokens(tokens, stemmer)\n    return tokens #stems\n\ntext = mycorpus[1000]\nlowers = text.lower()\nno_punctuation = lowers.translate(string.punctuation)\ntoken_list.append(no_punctuation)\n\nprint token_list\n#this can take some time\n#tfidf = TfidfVectorizer(tokenizer=tokenize, stop_words='english')\n#tfs = tfidf.fit_transform(token_dict.values())\n"

# %%
def myDecode(myStr):
    a = unicode(myStr).encode("UTF-8")
    a = a.decode("ASCII", errors="ignore")
    return a.replace('\n', " ")

# %%
mycorpus = map(myDecode, corpus.values)
s = set(stopwords.words('english'))
vectorizer = CountVectorizer(max_df=1)
X = vectorizer.fit_transform(mycorpus)
nomatchwords = vectorizer.get_feature_names()
s = s.union(nomatchwords)
#print s

vectorizer = CountVectorizer(stop_words=s)
X = vectorizer.fit_transform(mycorpus)
keywords = vectorizer.get_feature_names()

prog = re.compile(r"[0-9]")

for key in keywords:
    if prog.match(key):
        s.add(key)
    
vectorizer = TfidfVectorizer(stop_words=s)
X = vectorizer.fit_transform(mycorpus)

keywords = vectorizer.get_feature_names()
counts = X.sum(axis=0)
counts = np.array(counts.T).squeeze()
#print X.sum(1)
wc = zip(keywords,counts)
#wc = sorted(wc, key=lambda x: x[1])
len(wc)
# Out:
# 9090

# %%
"""
mycorpus = map(myDecode, corpus.values)
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(mycorpus)
keywords = vectorizer.get_feature_names()
counts = X.sum(axis=0)
counts = np.array(counts.T).squeeze()
#print X.sum(1)
wc = zip(keywords,counts)
wc = sorted(wc, key=lambda x: x[1], reverse=True)
print wc
#print keywords
#print mycorpus[3014]
"""
# Out:
# "\nmycorpus = map(myDecode, corpus.values)\nvectorizer = TfidfVectorizer(stop_words='english')\nX = vectorizer.fit_transform(mycorpus)\nkeywords = vectorizer.get_feature_names()\ncounts = X.sum(axis=0)\ncounts = np.array(counts.T).squeeze()\n#print X.sum(1)\nwc = zip(keywords,counts)\nwc = sorted(wc, key=lambda x: x[1], reverse=True)\nprint wc\n#print keywords\n#print mycorpus[3014]\n"

# %%
#stem
from nltk.stem.porter import PorterStemmer
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.regexp import RegexpStemmer
#stemmer = PorterStemmer() #, ignore_stopwords=True)
stemmer = SnowballStemmer("english", ignore_stopwords=True)
#stemmer = RegexpStemmer('ing$|ish$|py$|able$', min=4)
stemmer.stem("tastes")
#stemmer.stem("hoppy")
# Out:
# u'tast'

# %%
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()
wordnet_lemmatizer.lemmatize('complemented')
# Out:
# 'complemented'

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cs = cosine_similarity(X)
np.save("similarity",cs)
#py.pcolor(cs[:200,:200])
#py.show()
print cs.shape
print len(corpus)
# Out:
# (5768, 5768)
# 5768

# %%
from matplotlib import pyplot as py
import numpy as np

# %%
#myName = "Deschutes Black Butte Porter"
#myName = "Oskar Blues Old Chub"
#myName = "Dogfish Head 90 Minute Imperial IPA"
#myName = "Lagunitas A Little Sumpin"
#myName = "Victory HopDevil"
#myName = "Against the Grain Rico Sauvin"
#myName = "Prairie Artisan Ales Birra"
#myName = "Pabst Blue Ribbon"
#myName = "He'Brew Jewbelation"
myName = "Bud Light"
print df[df['name'].str.contains(myName)]
#print df.loc[6208].values
#print df[df['name'] == 'Stone India Pale Ale (IPA)']
a = df[df['name'] == myName]
#print a.index
ind = df.index.get_loc(a.index[0])
print ind
print a.description.values
# Out:
#                     Brewery              Style  \
# 4348   Anheuser-Busch InBev  Fruit Beer/Radler
# 4349   Anheuser-Busch InBev  Fruit Beer/Radler
# 4350   Anheuser-Busch InBev  Fruit Beer/Radler
# 4351   Anheuser-Busch InBev  Fruit Beer/Radler
# 4352   Anheuser-Busch InBev  Fruit Beer/Radler
# 8265   Anheuser-Busch InBev         Pale Lager
# 4347   Anheuser-Busch InBev          Wheat Ale
#
#                                             description  \
# 4348   Premium Light Beer with 100% Natural Lime Flavor
# 4349  Malt beverage with natural flavors, artificial...
# 4350  Margarita with a twist.\nMalt beverage with na...
# 4351  The beer based margarita is now introduced wit...
# 4352  Margaritas, the classic summer cocktail, are g...
# 8265  Introduced nationally in 1982, Bud Light is br...
# 4347  A light beer brewed with coriander and citrus ...
#
#                                name
# 4348                 Bud Light Lime
# 4349     Bud Light Lime Mang-o-Rita
# 4350    Bud Light Lime Raz-Ber-Rita
# 4351  Bud Light Lime Straw-Ber-Rita
# 4352          Bud Light Lime-a-Rita
# 8265                      Bud Light
# 4347         Bud Light Golden Wheat
# 4448
# [ u'Introduced nationally in 1982, Bud Light is brewed with a malt and hops ratio different from Budweiser for a distinctively crisp taste with fewer calories.']

# %%
#df = df.sort("Brewery")
df.to_pickle("beerDataFrame.pkl")

# %%
max(df.name.map(len))
# Out:
# 80

# %%
import pymysql as mdb
db = mdb.connect(user="jeckel", passwd="data", host="localhost", db="beerdb", charset='utf8')

with db:
   cur = db.cursor()
   cur.execute("DROP TABLE IF EXISTS ratebeer")
   cur.execute("CREATE TABLE ratebeer(id INT PRIMARY KEY,name VARCHAR(80))")
   for i,n in zip(df.index, df.name):
       cur.execute("INSERT INTO ratebeer(id, name) VALUES(%s, %s)", [str(i),n])
   db.commit()

# %%
similar = np.argsort(cs[ind,:])[::-1]
print cs[ind, similar[:20]]


df.loc[df.index[similar[:20]]]

#u = X[ind,:].nonzero()
#v = X[similar[-1],:].nonzero()
#df.loc[1195]

#np.sort()

#cs[115,:]

#sort
# Out:
# [ 1.          0.24366913  0.24304826  0.22268433  0.21044627  0.20447326
#   0.20077597  0.19903322  0.18221534  0.17929379  0.1717236   0.17134976
#   0.15952619  0.15473308  0.14382864  0.14218792  0.14147375  0.13983663
#   0.13918584  0.13515009]
#                                                 Brewery                 Style  \
# 8265                               Anheuser-Busch InBev            Pale Lager
# 9075                               Anheuser-Busch InBev    Amber Lager/Vienna
# 8289                                 Heineken Nederland            Pale Lager
# 8314                               Anheuser-Busch InBev            Pale Lager
# 8261                               Anheuser-Busch InBev            Pale Lager
# 8290                               Anheuser-Busch InBev            Pale Lager
# 8353                                 Heineken Nederland            Pale Lager
# 4042                        New Holland Brewing Company   American Strong Ale
# 3321                                Boston Beer Company         Premium Lager
# 8299                Coors Brewing Company (MillerCoors)            Pale Lager
# 8266                Coors Brewing Company (MillerCoors)            Pale Lager
# 8959                                  Boon Rawd Brewery         Premium Lager
# 4352                               Anheuser-Busch InBev     Fruit Beer/Radler
# 1522                Coors Brewing Company (MillerCoors)           Low Alcohol
# 3081                           Shipyard Brewing Company  Golden Ale/Blond Ale
# 7897   Leinenkugel Brewing Company (Tenth & Blake Be...             Wheat Ale
# 7778                         Central Waters Brewing Co.  India Pale Ale (IPA)
# 8321                               Anheuser-Busch InBev            Pale Lager
# 8308                               Anheuser-Busch InBev            Pale Lager
# 3881                           Founders Brewing Company                Porter
#
#                                             description  \
# 8265  Introduced nationally in 1982, Bud Light is br...
# 9075  With a blend of two-row caramel malt and four ...
# 8289  A special light beer containing only 3.5% alco...
# 8314  Introduced in 1994, Bud Ice is a smooth-tastin...
# 8261  Brewed and sold since 1876, "The King of Beers...
# 8290  Natural Light is brewed with a blend of premiu...
# 8353  Brewed in the same high quality tradition as t...
# 4042  The ratio Phi was discovered by ancient schola...
# 3321  It took 2 years of brewing, tasting and testin...
# 8299  Introduced in 1989, Keystone Light is a refres...
# 8266  A premium light beer with 105 calories per 12-...
# 8959  A premium lager beer brewed from the finest in...
# 4352  Margaritas, the classic summer cocktail, are g...
# 1522  The responsible choice in a premium nonalcohol...
# 3081  Shipyard Light Beer is a crisp, dry, pleasing ...
# 7897  Honey Weiss has a taste that's light, crisp an...
# 7778  This is the brewery’s newest beer, this Americ...
# 8321  Introduced in 1978 as the country's first supe...
# 8308  American-style lager that is long brewed for a...
# 3881  Founders Brewing Company is proud to be one of...
#
#                                   name
# 8265                         Bud Light
# 9075             Budweiser Black Crown
# 8289                      Amstel Light
# 8314                           Bud Ice
# 8261                         Budweiser
# 8290                     Natural Light
# 8353            Heineken Premium Light
# 4042                   New Holland Phi
# 3321                   Sam Adams Light
# 8299                    Keystone Light
# 8266                       Coors Light
# 8959                            Singha
# 4352             Bud Light Lime-a-Rita
# 1522               Coors Non-Alcoholic
# 3081                    Shipyard Light
# 7897     Leinenkugels Honey Weiss Bier
# 7778  Central Waters Glacial Trail IPA
# 8321                    Michelob Light
# 8308                  Budweiser Select
# 3881       Founders American Black Ale

# %%
from sklearn.decomposition import TruncatedSVD
svd = TruncatedSVD(n_components=4, random_state=99)
allRevsSVD=svd.fit_transform(X)

print(svd.explained_variance_ratio_.sum())
# Out:
# 0.0268832001814

# %%
print allRevsSVD.shape
print X.shape
# Out:
# (5768, 10)
# (5768, 9090)

# %%
df_additional = df.copy()

# %%
for i in range(4):
    df_additional['pca'+str(i)] = pd.DataFrame(allRevsSVD[:,i], index=df_additional.index)

# %%
import seaborn as sns
sns.set_context("talk")
sns.set_palette("colorblind")
grpby = df_additional.groupby("Style")
mycount = grpby.count().sort('name', ascending=False)
for i in range(4):
    for j in range(i+1,4):
        py.figure()
        for name, group in grpby:
            if name in ["India Pale Ale (IPA)", "Wheat Ale", "Porter"]:
                py.plot(group['pca'+str(i)], group['pca'+str(j)], 'o', label=name)
                py.xlabel("Dimension "+str(i))
                py.ylabel("Dimension "+str(j))
        py.legend()
py.show()

# %%
topstyles = mycount.head(12).index.values
mystyles = [u'India Pale Ale', "Wheat Ale", "Porter"]
print topstyles
# Out:
# [u'India Pale Ale (IPA)' u'Imperial Stout' u'Imperial/Double IPA'
#  u'American Strong Ale' u'Barley Wine' u'Porter' u'Saison'
#  u'Fruit Beer/Radler' u'Amber Ale' u'Brown Ale' u'Wheat Ale'
#  u'Belgian White (Witbier)']

# %%
py.figure()
mylist = []
for s in mystyles:
    mylist.append(df_additional[df_additional.Style.str.contains(s)].pca1)

#for d,s in zip(mylist, mystyles):
#    py.hist(d.values, bins=40, range=[-.25, .6], normed=True, label=s)
py.hist(mylist, bins=10, range=[-.25, .6], normed=True, label=mystyles)
py.legend()
py.show()

# %%
df_subset = df_additional[df_additional.Style.str.contains(mystyles[0])]
df_subset.Style
# Out:
# Series([], name: Style, dtype: object)

# %%
# 8420  Acme IPA is profoundly hoppy, finished with ov...
# 8425  Mikkeller’s tribute to the green gold.\nMikkel...
# 8427  A rich, malty, and very bitter ale. Cascade ho...
# 8430  Bottle conditioned. Also available on keg (fil...
# 8438  Earlier batches brewed by Mikkeller at Ørbæk B...
# 8443  Label on photo is wrong.\nThe first in a new s...
# 8450  A Northwest interpretation of a classic Englis...
# 8456  Bottle; Pasteurised. Has been seen on draught....
# 8459  Bittering hops Galena; as latehops Chinook, Ca...
#
#                                                    name      pca0      pca1  \
# 1                        Straight To Ale Monkeynaut IPA  0.108802 -0.042263
# 7                                   Alaskan Icy Bay IPA  0.137199 -0.073971
# 26                                          Glacier IPA  0.149884 -0.042490
# 67                         Midnight Sun Sockeye Red IPA  0.213622 -0.089436
# 83                  21st Amendment Brew Free or Die IPA  0.216883 -0.130387
# 110                                        AleSmith IPA  0.209765 -0.031918
# 165                    Alpine Beer Company O’Briens IPA  0.163595 -0.069688
# 171                            Alpine Beer Company Duet  0.131951 -0.060269
# 173                      Alpine Beer Company Nelson IPA  0.185942 -0.022769
# 177   Anderson Valley Bahl Hornin’ Spring India Pale...  0.178776 -0.077557
# 190                       Anderson Valley Hop Ottin IPA  0.184845 -0.081964
# 200                                      Angel City IPA  0.195413 -0.079339
# 201                     Auburn Alehouse Gold Digger IPA  0.225242 -0.132745
# 204                           Ballast Point Big Eye IPA  0.224107 -0.089346
# 225                           Ballast Point Sculpin IPA  0.131517 -0.031189
# 237                               Beachwood Melrose IPA  0.245376 -0.095161
# 259                           Bear Republic Racer 5 IPA  0.312793 -0.106920
# 273                                   Bison Organic IPA  0.178074 -0.079839
# 281                       Black Diamond Jagged Edge IPA  0.271077 -0.110529
# 284                          Black Diamond Wheat Wacker  0.226959 -0.076563
# 286                                Black Market Rye IPA  0.266111 -0.111016
# 297                          Bootleggers Rustic Rye IPA  0.184732 -0.056107
# 300                              Cismontane Coulter IPA  0.192998 -0.031125
# 302            Coronado / Maui Two Islands Hibiscus IPA  0.109643 -0.013380
# 309                             Coronado Hoppy Daze IPA  0.115829 -0.008556
# 311                               Coronado Islander IPA  0.112365 -0.055603
# 327                        Drakes Aroma Coma IPA (6.7%)  0.234815 -0.089741
# 337                                          Drakes IPA  0.264713 -0.113588
# 344                              Mikkeller Invasion IPA  0.042207  0.020234
# 345                             Dust Bowl Hops Of Wrath  0.195355 -0.053945
# ...                                                 ...       ...       ...
# 8014                        Minhas Thumper American IPA  0.046556 -0.033524
# 8038                                     Hopothesis IPA  0.161685 -0.066242
# 8055                          New Glarus Hop Hearty Ale  0.254386 -0.045963
# 8117                               Oso Hop Whoopin! IPA  0.152988 -0.009610
# 8126                            Potosi Snake Hollow IPA  0.259381 -0.112560
# 8134                           Sand Creek Wild Ride IPA  0.221597 -0.089847
# 8137                                   BluCreek Zen IPA  0.198466 -0.079362
# 8143                          Harbor City Full Tilt IPA  0.171287 -0.032322
# 8152                          Pangaea Liljas Argosy IPA  0.207834 -0.077715
# 8154                    Pangaea Liljas Hop Nest Monster  0.159868 -0.046733
# 8184                          Chameleon Ryediculous IPA  0.189975 -0.094870
# 8199                                     Point IPA (UK)  0.260373 -0.130897
# 8222      Tyranena BGW Bitter Woman From Hell Extra IPA  0.060483 -0.013333
# 8223               Tyranena BGW Bitter Woman In The Rye  0.110284 -0.012987
# 8233                 Tyranena BGW Stickin It To The Man  0.143125  0.021491
# 8236                          Tyranena Bitter Woman IPA  0.188743 -0.101454
# 8245                                Tyranena Scurvy IPA  0.177726 -0.095357
# 8395                            BrewDog Punk IPA (5.6%)  0.179895 -0.053384
# 8410                              BrewDog Punk IPA (6%)  0.184114 -0.036325
# 8413                       Dieu du Ciel Corne du Diable  0.183462 -0.067874
# 8415                                 Thornbridge Jaipur  0.114477 -0.030097
# 8420                                Acme California IPA  0.119893 -0.003401
# 8425                               Mikkeller Green Gold  0.027928 -0.011172
# 8427                             Nøgne Ø India Pale Ale  0.233457 -0.066777
# 8430                            Meantime India Pale Ale  0.128386 -0.032221
# 8438                                Mikkeller Stateside  0.211396 -0.077138
# 8443                    Mikkeller Single Hop Simcoe IPA  0.190675 -0.073068
# 8450                           Elysian The Immortal IPA  0.219691 -0.104479
# 8456                 Belhaven Twisted Thistle IPA (USA)  0.172779 -0.048634
# 8459               De Molen Vuur & Vlam (Fire & Flames)  0.074540 -0.057570
#
#           pca2      pca3
# 1    -0.013925  0.026068
# 7    -0.011961  0.080859
# 26    0.019713  0.100186
# 67   -0.048738  0.118678
# 83   -0.105440  0.177176
# 110  -0.050586  0.015804
# 165  -0.070786  0.134992
# 171  -0.014222  0.187400
# 173  -0.011964  0.050744
# 177   0.016294 -0.003594
# 190  -0.092032  0.092417
# 200  -0.029449  0.120723
# 201  -0.103601  0.185581
# 204  -0.042840  0.183963
# 225   0.021886  0.063829
# 237  -0.056014  0.147512
# 259   0.045041  0.138203
# 273  -0.070188  0.123377
# 281  -0.099811  0.147232
# 284   0.126776  0.015095
# 286  -0.066884  0.159875
# 297  -0.043483  0.112835
# 300  -0.035009  0.039567
# 302   0.041392  0.042691
# 309   0.064147  0.049090
# 311  -0.034682  0.102501
# 327  -0.027520  0.134692
# 337  -0.029671  0.065249
# 344   0.033469  0.010037
# 345   0.047044  0.079751
# ...        ...       ...
# 8014 -0.013765  0.089694
# 8038 -0.026908  0.117002
# 8055 -0.068131  0.112924
# 8117  0.061740  0.080437
# 8126 -0.062406  0.170934
# 8134 -0.067920  0.027153
# 8137 -0.010357  0.116729
# 8143 -0.070192  0.003617
# 8152  0.031691  0.071943
# 8154 -0.022115  0.136815
# 8184 -0.076795  0.103067
# 8199 -0.039087  0.146820
# 8222 -0.037692  0.021899
# 8223 -0.006768  0.076653
# 8233 -0.074888 -0.078114
# 8236 -0.049340  0.149222
# 8245  0.052177  0.123475
# 8395  0.023649  0.047497
# 8410  0.016267  0.001500
# 8413 -0.026760  0.087623
# 8415 -0.008565  0.032882
# 8420  0.006141  0.114341
# 8425 -0.001019  0.036079
# 8427  0.011700  0.012561
# 8430  0.037352  0.060849
# 8438 -0.015998  0.077859
# 8443  0.016658  0.144450
# 8450 -0.048566  0.027249
# 8456  0.010530  0.079615
# 8459 -0.036143  0.113381
#
# [708 rows x 8 columns]
